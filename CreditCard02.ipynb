# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('creditcard.csv')
df['Time_hours'] = df['Time'] / 3600
plt.figure(figsize=(10, 6))
plt.scatter(df['Time_hours'][df['Class'] == 1], df['Amount'][df['Class'] == 1], c='red', label='Fraud', s=20)
plt.scatter(df['Time_hours'][df['Class'] == 0], df['Amount'][df['Class'] == 0], c='lightblue', label='Non-Fraud', alpha=0.05, s=10)
plt.yscale('log')
plt.title('Transaction Amount vs. Time by Class')
plt.xlabel('Time (Hours)')
plt.ylabel('Amount')
plt.legend()
plt.show()
print(df[df['Class'] == 1]['Amount'].describe())
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Time_hours'], bins=50)
plt.axvline(x=12, color='r', linestyle='--', label='Midday Peak 1')
plt.axvline(x=36, color='r', linestyle='--', label='Midday Peak 2')
plt.title('Transaction Time Distribution (Hours)')
plt.xlabel('Time (Hours)')
plt.ylabel('Count')
plt.legend()
plt.show()
