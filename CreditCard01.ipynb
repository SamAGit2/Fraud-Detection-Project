# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('creditcard.csv')
# Log-transformed histogram
plt.figure(figsize=(10, 6))
sns.histplot(np.log1p(df['Amount']), bins=50)
plt.title('Log-Transformed Transaction Amount Distribution')
plt.xlabel('Log(Amount)')
plt.ylabel('Count')
plt.show()
# Fraud vs. non-fraud countplot with log y-axis
plt.figure(figsize=(6, 4))
sns.countplot(x='Class', data=df)
plt.yscale('log')
plt.ylim(1, 10**5.4)  # Show up to ~250,000
plt.title('Fraud vs. Non-Fraud Counts (Log Scale)')
plt.xlabel('Class (0=Non-Fraud, 1=Fraud)')
plt.ylabel('Count (Log Scale)')
plt.show()

# %%
# Log-transformed histogram and countplot with log y-axis for imbalanced class data
